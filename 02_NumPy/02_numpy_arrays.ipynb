# %%
import numpy as np

# %%
sample_array = np.array([1, 2, 3])
sample_array

# %%
ones = np.ones((2,3))
print(ones)
print(ones.dtype)

# %%
zeros = np.zeros((2,3))
zeros

# %%
range_array = np.arange(0, 10, 2)
range_array

# %%
random_array = np.random.randint(0, 10, size=(3, 5))
random_array

# %%
random_array_2 = np.random.random((5,3))
random_array_2

# %%
# Pseudo random numbers
# random.seed allows us to reproduce random numbers which are still reproducable
np.random.seed(seed=120)
random_array_3 = np.random.randint(10, size = (5, 3))
random_array_3

# %%
# Viewing arrays and matrices
np.unique(random_array_3)

# %%
random_array

# %%
print(random_array[0])
print(random_array[:2])

# %%
print(random_array[0][:4])
