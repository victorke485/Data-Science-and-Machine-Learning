# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales["Price"] = car_sales["Price"].str.replace(pat={"$": "", ",": "", ".": ""}).astype(int) / 100
car_sales.head()

# %%
plt.style.available

# %%
car_sales["Price"].plot()

# %%
# Styling

# plt.style.use("seaborn-v0_8")
# plt.style.use("tableau-colorblind10")
# plt.style.use("dark_background")
# plt.style.use("seaborn-v0_8-bright")
# plt.style.use("seaborn-v0_8-poster")
# plt.style.use("seaborn-v0_8")
plt.style.use("default")



car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
heart_desease = pd.read_csv("heart-disease.csv")
over_50 = heart_desease[heart_desease["age"] > 50]

# %%
fig, ax = plt.subplots(figsize=(10, 6))

scatter = ax.scatter(x=over_50["age"], y=over_50["chol"], c=over_50["target"], cmap="plasma")

# Customize
ax.set(
    title="Heart Disease and Cholesterol Levels",
    xlabel="Age",
    ylabel="Cholesterol"
)

# Add legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line
ax.axhline(over_50["chol"].mean(), linestyle="--")

# %%
# Customizing the x and y axis
# Subplot of chol, age, thelach
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, figsize=(10, 10), sharex=True)

# ax0
scatter = ax0.scatter(x=over_50["age"], y=over_50["chol"], c=over_50["target"],cmap="winter")
ax0.set(
    title="Heart Disease and Cholesterol Levels", ylabel="Cholesterol"
)
ax0.set_xlim([50, 80])
ax0.legend(*scatter.legend_elements(), title="Target")
ax0.axhline(over_50["chol"].mean(), linestyle="--")

# ax1
scatter = ax1.scatter(x=over_50["age"], y=over_50["thalach"], c=over_50["target"], cmap="plasma")
ax1.set(
    title="Heart Disease and Max Heart Rate", xlabel="Age", ylabel="Max Heart Rate"
)
ax1.legend(*scatter.legend_elements(), title="Target")
ax1.axhline(over_50["thalach"].mean(), linestyle="--")

# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")

# Saving
fig.savefig("heart-disease-analysis.png")
